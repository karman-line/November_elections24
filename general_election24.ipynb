# %% [markdown]
# # Postelection data analysis #
#
# #### Nobody said it was going to be fun. But hey! Here we are. In this notebook we: ####
# * build an ASCII file parser (more like a .txt parser)
# * clean up Nassau data courtesy of Rita and TC
# * clean up Suffolk data, courtest of BOE (not pleased about the ASCII format) [No Suffolk data here. All of it is in Excel].
# * Put it all together so we have one file that has results for the local race as well as presidential

# %%
import pandas as pd
import numpy as np
import re

# %%
# Path to the .txt file which holds Suffolk data
file_path = 'Results and analysis/24GE_res.txt'

# Define a dictionary for Town Codes
town_codes = {
    "0": "Shelter Island",
    "1": "Brookhaven",
    "2": "Huntington",
    "3": "Islip",
    "4": "Babylon",
    "5": "Smithtown",
    "6": "Southampton",
    "7": "East Hampton",
    "8": "Southold",
    "9": "Riverhead"
}

# %%
# Initialize structures to hold parsed data
ed_data = []
candidates = []

# Open and read the .txt file
with open(file_path, 'r') as file:
    lines = file.readlines()

    for line in lines:
        record_type = line[4]  # The fifth character indicates record type

        if record_type == 'R':
            # Reset the candidate list for each new race
            candidates = []

        elif record_type == 'C':
            # Parse candidate information and add to list of candidates for the current race
            candidate_name = line[5:30].strip()
            party_code = line[30:33].strip()
            row_lever = line[41:44].strip()
            # Combine candidate name with party for a unique identifier
            candidates.append({
                'name': f"{candidate_name} ({party_code})",
                'row_lever': row_lever
            })

        elif record_type == 'E' and candidates:
            # Parse the ED record
            ed_number = line[6:9].strip()
            town_code = line[5:6]
            congressional_district = line[34:35].strip()
            senatorial_district = line[35:36].strip()
            assembly_district = line[36:38].strip()
            legislative_district = line[38:40].strip()

            # Format ED number to be zero-padded (e.g., '013' for ED 13)
            ed_number_padded = ed_number.zfill(3)
            precinct_name = f"{town_code}{ed_number_padded}"  # Create precinct_name as four-character string

            # Initialize a dictionary for each ED entry with location information
            ed_record = {
                'ED': ed_number,
                'Town Code': town_code,
                'Town': town_codes.get(town_code, "Unknown"),
                'precinct_name': precinct_name,
                'Congressional District': congressional_district,
                'Senatorial District': senatorial_district,
                'Assembly District': assembly_district,
                'Legislative District': legislative_district
            }

            # Calculate the starting position for votes in the E record
            vote_start_position = 52
            # Loop through each candidate and retrieve their vote count from the correct position
            for idx, candidate in enumerate(candidates):
                # Each vote block for a candidate is 4 characters long
                vote_start = vote_start_position + (idx * 4)
                vote_end = vote_start + 4
                candidate_votes = int(line[vote_start:vote_end].strip() or '0')

                # Add candidate vote to the ED record using candidate's name as the column
                ed_record[candidate['name']] = candidate_votes

            # Append structured ED record to the list
            ed_data.append(ed_record)

# %%
# Convert the parsed ED data to a DataFrame, aligning columns by candidate name across EDs
df_ed_votes = pd.DataFrame(ed_data)

# Save to a CSV file
df_ed_votes.to_csv('Results and analysis/suffolk_output.csv', index=False)

print(f"Data saved to {'Results and analysis/suffolk_output.csv'}")
# Out:
# Data saved to Results and analysis/suffolk_output.csv

# %%
df_ed_votes
# Out:
#        ED Town Code            Town precinct_name Congressional District  \
# 0     001         0  Shelter Island          0001                      1
# 1     002         0  Shelter Island          0002                      1
# 2     003         0  Shelter Island          0003                      1
# 3     004         0  Shelter Island          0004                      1
# 4     001         1      Brookhaven          1001                      1
# ...   ...       ...             ...           ...                    ...
# 9385  038         6     Southampton          6038                      1
# 9386  039         6     Southampton          6039                      1
# 9387  040         6     Southampton          6040                      1
# 9388  041         6     Southampton          6041                      1
# 9389  042         6     Southampton          6042                      1
#
#      Senatorial District Assembly District Legislative District  \
# 0                      1                 1                    1
# 1                      1                 1                    1
# 2                      1                 1                    1
# 3                      1                 1                    1
# 4                      1                 4                    5
# ...                  ...               ...                  ...
# 9385                   1                 1                    2
# 9386                   1                 1                    2
# 9387                   1                 1                    2
# 9388                   1                 1                    1
# 9389                   1                 1                    2
#
#       Harris, Kamala D (DEM)  Harris, Kamala D (WOR)  ...  Shaw, Lisa (IAC)  \
# 0                      239.0                    21.0  ...               NaN
# 1                      272.0                    21.0  ...               NaN
# 2                      261.0                    10.0  ...               NaN
# 3                      283.0                    11.0  ...               NaN
# 4                      395.0                    13.0  ...               NaN
# ...                      ...                     ...  ...               ...
# 9385                     NaN                     NaN  ...               NaN
# 9386                     NaN                     NaN  ...               NaN
# 9387                     NaN                     NaN  ...               NaN
# 9388                     NaN                     NaN  ...               NaN
# 9389                     NaN                     NaN  ...               NaN
#
#       Damato, Paul L (REP)  Damato, Paul L (CON)  Scheuring, Maria C (DEM)  \
# 0                      NaN                   NaN                       NaN
# 1                      NaN                   NaN                       NaN
# 2                      NaN                   NaN                       NaN
# 3                      NaN                   NaN                       NaN
# 4                      NaN                   NaN                       NaN
# ...                    ...                   ...                       ...
# 9385                   NaN                   NaN                       NaN
# 9386                   NaN                   NaN                       NaN
# 9387                   NaN                   NaN                       NaN
# 9388                   NaN                   NaN                       NaN
# 9389                   NaN                   NaN                       NaN
#
#       Zollo, John B (REP)  Zollo, John B (CON)  Grossman, Adam B (DEM)  \
# 0                     NaN                  NaN                     NaN
# 1                     NaN                  NaN                     NaN
# 2                     NaN                  NaN                     NaN
# 3                     NaN                  NaN                     NaN
# 4                     NaN                  NaN                     NaN
# ...                   ...                  ...                     ...
# 9385                  NaN                  NaN                   189.0
# 9386                  NaN                  NaN                   324.0
# 9387                  NaN                  NaN                   140.0
# 9388                  NaN                  NaN                   182.0
# 9389                  NaN                  NaN                   308.0
#
#       Grossman, Adam B (CON)  Sartain, Karen M (DEM)  Sartain, Karen M (CON)
# 0                        NaN                     NaN                     NaN
# 1                        NaN                     NaN                     NaN
# 2                        NaN                     NaN                     NaN
# 3                        NaN                     NaN                     NaN
# 4                        NaN                     NaN                     NaN
# ...                      ...                     ...                     ...
# 9385                    88.0                   185.0                    80.0
# 9386                   117.0                   326.0                   108.0
# 9387                    96.0                   139.0                    83.0
# 9388                    68.0                   191.0                    64.0
# 9389                    92.0                   311.0                    85.0
#
# [9390 rows x 154 columns]

# %% [markdown]
# ## Part 2
#
# Using the ASCII file TC McCarthy parsed with his instant-built [parser](https://github.com/newsdaycom/ASC2CSV/tree/main), we are going to look for some local results.

# %%
gen = pd.read_csv('Map data/GEN2024_preliminary.csv')
# Out:
# /var/folders/3w/v4769sl91ks57hsf6mhcg5_wglchws/T/ipykernel_33658/597256256.py:1: DtypeWarning: Columns (6,7,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   gen = pd.read_csv('Map data/GEN2024_preliminary.csv')

# %%
gen.head(6)
# Out:
#    contest_num  candidate_num  precinct_code  reg_voter_count  ballots_cast  \
# 0          1.0            1.0            1.0              0.0           0.0
# 1          1.0            1.0            2.0              0.0           0.0
# 2          1.0            1.0            3.0              0.0           0.0
# 3          1.0            1.0            4.0              0.0           0.0
# 4          1.0            1.0            5.0              0.0           0.0
# 5          1.0            1.0            6.0              0.0           0.0
#
#   party_code district_type_id district_code              contest_title  \
# 0        NaN              NaN           NaN  REGISTERED VOTERS - TOTAL
# 1        NaN              NaN           NaN  REGISTERED VOTERS - TOTAL
# 2        NaN              NaN           NaN  REGISTERED VOTERS - TOTAL
# 3        NaN              NaN           NaN  REGISTERED VOTERS - TOTAL
# 4        NaN              NaN           NaN  REGISTERED VOTERS - TOTAL
# 5        NaN              NaN           NaN  REGISTERED VOTERS - TOTAL
#
#               candidate_name  precinct_name district_name  votes_allowed  \
# 0  REGISTERED VOTERS - TOTAL       113001.0           NaN            0.0
# 1  REGISTERED VOTERS - TOTAL       113002.0           NaN            0.0
# 2  REGISTERED VOTERS - TOTAL       113003.0           NaN            0.0
# 3  REGISTERED VOTERS - TOTAL       113004.0           NaN            0.0
# 4  REGISTERED VOTERS - TOTAL       113005.0           NaN            0.0
# 5  REGISTERED VOTERS - TOTAL       113006.0           NaN            0.0
#
#    referendum_flag  cr_code  lf_code
# 0              NaN      NaN      NaN
# 1              NaN      NaN      NaN
# 2              NaN      NaN      NaN
# 3              NaN      NaN      NaN
# 4              NaN      NaN      NaN
# 5              NaN      NaN      NaN

# %%
# Convert precinct_name to text

gen = gen.dropna(subset=['precinct_name'])
gen['precinct_name'] = gen['precinct_name'].astype(int).astype(str)
gen
# Out:
#         contest_num  candidate_num  precinct_code  reg_voter_count  \
# 0               1.0            1.0            1.0              0.0
# 1               1.0            1.0            2.0              0.0
# 2               1.0            1.0            3.0              0.0
# 3               1.0            1.0            4.0              0.0
# 4               1.0            1.0            5.0              0.0
# ...             ...            ...            ...              ...
# 106403        131.0            4.0         1076.0              1.0
# 106404        131.0            4.0         1077.0              1.0
# 106405        131.0            4.0         1078.0             18.0
# 106406        131.0            4.0         1079.0             20.0
# 106407        131.0            4.0         1080.0              0.0
#
#         ballots_cast party_code district_type_id district_code  \
# 0                0.0        NaN              NaN           NaN
# 1                0.0        NaN              NaN           NaN
# 2                0.0        NaN              NaN           NaN
# 3                0.0        NaN              NaN           NaN
# 4                0.0        NaN              NaN           NaN
# ...              ...        ...              ...           ...
# 106403           1.0        NaN              NaN           NaN
# 106404           1.0        NaN              NaN           NaN
# 106405          18.0        NaN              NaN           NaN
# 106406          20.0        NaN              NaN           NaN
# 106407           0.0        NaN              NaN           NaN
#
#                             contest_title             candidate_name  \
# 0               REGISTERED VOTERS - TOTAL  REGISTERED VOTERS - TOTAL
# 1               REGISTERED VOTERS - TOTAL  REGISTERED VOTERS - TOTAL
# 2               REGISTERED VOTERS - TOTAL  REGISTERED VOTERS - TOTAL
# 3               REGISTERED VOTERS - TOTAL  REGISTERED VOTERS - TOTAL
# 4               REGISTERED VOTERS - TOTAL  REGISTERED VOTERS - TOTAL
# ...                                   ...                        ...
# 106403  Proposal Number One, An Amendment                UNDER VOTES
# 106404  Proposal Number One, An Amendment                UNDER VOTES
# 106405  Proposal Number One, An Amendment                UNDER VOTES
# 106406  Proposal Number One, An Amendment                UNDER VOTES
# 106407  Proposal Number One, An Amendment                UNDER VOTES
#
#        precinct_name district_name  votes_allowed  referendum_flag  cr_code  \
# 0             113001           NaN            0.0              NaN      NaN
# 1             113002           NaN            0.0              NaN      NaN
# 2             113003           NaN            0.0              NaN      NaN
# 3             113004           NaN            0.0              NaN      NaN
# 4             113005           NaN            0.0              NaN      NaN
# ...              ...           ...            ...              ...      ...
# 106403        517042           NaN            1.0              NaN      NaN
# 106404        517043           NaN            1.0              NaN      NaN
# 106405        517044           NaN            1.0              NaN      NaN
# 106406        517045           NaN            1.0              NaN      NaN
# 106407        218073           NaN            1.0              NaN      NaN
#
#         lf_code
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 106403      NaN
# 106404      NaN
# 106405      NaN
# 106406      NaN
# 106407      NaN
#
# [106408 rows x 16 columns]

# %%
gen[gen['candidate_name'].isin(['OVER VOTES','UNDER VOTES','WRITE-IN'])]['ballots_cast'].sum()
# Out:
# 1805285.0

# %%
# Drop the over votes, under votes and write-ins.
# Unofficial results don't include them

gen = gen[~gen['candidate_name'].isin(['OVER VOTES','UNDER VOTES','WRITE-IN'])]

# %%
gen[gen['contest_title']=='BALLOTS CAST - TOTAL']
# Out:
#       contest_num  candidate_num  precinct_code  reg_voter_count  \
# 1080          2.0            1.0            1.0            867.0
# 1081          2.0            1.0            2.0            657.0
# 1082          2.0            1.0            3.0            460.0
# 1083          2.0            1.0            4.0            796.0
# 1084          2.0            1.0            5.0            582.0
# ...           ...            ...            ...              ...
# 2155          2.0            1.0         1076.0              1.0
# 2156          2.0            1.0         1077.0             34.0
# 2157          2.0            1.0         1078.0            348.0
# 2158          2.0            1.0         1079.0            295.0
# 2159          2.0            1.0         1080.0              0.0
#
#       ballots_cast party_code district_type_id district_code  \
# 1080         867.0        NaN              NaN           NaN
# 1081         657.0        NaN              NaN           NaN
# 1082         460.0        NaN              NaN           NaN
# 1083         796.0        NaN              NaN           NaN
# 1084         582.0        NaN              NaN           NaN
# ...            ...        ...              ...           ...
# 2155           1.0        NaN              NaN           NaN
# 2156          34.0        NaN              NaN           NaN
# 2157         348.0        NaN              NaN           NaN
# 2158         295.0        NaN              NaN           NaN
# 2159           0.0        NaN              NaN           NaN
#
#              contest_title        candidate_name precinct_name district_name  \
# 1080  BALLOTS CAST - TOTAL  BALLOTS CAST - TOTAL        113001           NaN
# 1081  BALLOTS CAST - TOTAL  BALLOTS CAST - TOTAL        113002           NaN
# 1082  BALLOTS CAST - TOTAL  BALLOTS CAST - TOTAL        113003           NaN
# 1083  BALLOTS CAST - TOTAL  BALLOTS CAST - TOTAL        113004           NaN
# 1084  BALLOTS CAST - TOTAL  BALLOTS CAST - TOTAL        113005           NaN
# ...                    ...                   ...           ...           ...
# 2155  BALLOTS CAST - TOTAL  BALLOTS CAST - TOTAL        517042           NaN
# 2156  BALLOTS CAST - TOTAL  BALLOTS CAST - TOTAL        517043           NaN
# 2157  BALLOTS CAST - TOTAL  BALLOTS CAST - TOTAL        517044           NaN
# 2158  BALLOTS CAST - TOTAL  BALLOTS CAST - TOTAL        517045           NaN
# 2159  BALLOTS CAST - TOTAL  BALLOTS CAST - TOTAL        218073           NaN
#
#       votes_allowed  referendum_flag  cr_code  lf_code
# 1080            0.0              NaN      NaN      NaN
# 1081            0.0              NaN      NaN      NaN
# 1082            0.0              NaN      NaN      NaN
# 1083            0.0              NaN      NaN      NaN
# 1084            0.0              NaN      NaN      NaN
# ...             ...              ...      ...      ...
# 2155            0.0              NaN      NaN      NaN
# 2156            0.0              NaN      NaN      NaN
# 2157            0.0              NaN      NaN      NaN
# 2158            0.0              NaN      NaN      NaN
# 2159            0.0              NaN      NaN      NaN
#
# [1080 rows x 16 columns]

# %%
gen[gen['contest_title']=='BALLOTS CAST - TOTAL'].to_csv('ballots_total.csv')

# %%
# Drop the races we ain't interested in

gen = gen[~gen['contest_title'].isin(['BALLOTS CAST - BLANK','BALLOTS CAST - TOTAL','County Court Judge','District Court Judge District 4','Family Court Judge','Justice of the Supreme Court','Proposal Number One, An Amendment','REGISTERED VOTERS - TOTAL'])]

# %%
gen['total'] = gen.groupby(['precinct_name','contest_title'])['ballots_cast'].transform('sum')
gen
# Out:
#         contest_num  candidate_num  precinct_code  reg_voter_count  \
# 3240          101.0            1.0            1.0            387.0
# 3241          101.0            1.0            2.0            333.0
# 3242          101.0            1.0            3.0            240.0
# 3243          101.0            1.0            4.0            346.0
# 3244          101.0            1.0            5.0            275.0
# ...             ...            ...            ...              ...
# 102011        130.0            3.0          634.0             24.0
# 102012        130.0            3.0          635.0             30.0
# 102013        130.0            3.0          636.0             25.0
# 102014        130.0            3.0          637.0             17.0
# 102015        130.0            3.0          638.0             18.0
#
#         ballots_cast party_code district_type_id district_code  \
# 3240           387.0        DEM              NaN           NaN
# 3241           333.0        DEM              NaN           NaN
# 3242           240.0        DEM              NaN           NaN
# 3243           346.0        DEM              NaN           NaN
# 3244           275.0        DEM              NaN           NaN
# ...              ...        ...              ...           ...
# 102011          24.0        CON              CTC           TLB
# 102012          30.0        CON              CTC           TLB
# 102013          25.0        CON              CTC           TLB
# 102014          17.0        CON              CTC           TLB
# 102015          18.0        CON              CTC           TLB
#
#                                             contest_title    candidate_name  \
# 3240    Presidential Electors for President and Vice P...  Kamala D. Harris
# 3241    Presidential Electors for President and Vice P...  Kamala D. Harris
# 3242    Presidential Electors for President and Vice P...  Kamala D. Harris
# 3243    Presidential Electors for President and Vice P...  Kamala D. Harris
# 3244    Presidential Electors for President and Vice P...  Kamala D. Harris
# ...                                                   ...               ...
# 102011                      City Judge City of Long Beach    Corey E. Klein
# 102012                      City Judge City of Long Beach    Corey E. Klein
# 102013                      City Judge City of Long Beach    Corey E. Klein
# 102014                      City Judge City of Long Beach    Corey E. Klein
# 102015                      City Judge City of Long Beach    Corey E. Klein
#
#        precinct_name       district_name  votes_allowed  referendum_flag  \
# 3240          113001                 NaN            1.0              NaN
# 3241          113002                 NaN            1.0              NaN
# 3242          113003                 NaN            1.0              NaN
# 3243          113004                 NaN            1.0              NaN
# 3244          113005                 NaN            1.0              NaN
# ...              ...                 ...            ...              ...
# 102011        320020  City of Long Beach            1.0              NaN
# 102012        320021  City of Long Beach            1.0              NaN
# 102013        320022  City of Long Beach            1.0              NaN
# 102014        320023  City of Long Beach            1.0              NaN
# 102015        320024  City of Long Beach            1.0              NaN
#
#         cr_code  lf_code  total
# 3240        NaN      NaN  847.0
# 3241        NaN      NaN  642.0
# 3242        NaN      NaN  451.0
# 3243        NaN      NaN  789.0
# 3244        NaN      NaN  573.0
# ...         ...      ...    ...
# 102011      NaN      NaN  517.0
# 102012      NaN      NaN  640.0
# 102013      NaN      NaN  728.0
# 102014      NaN      NaN  516.0
# 102015      NaN      NaN  531.0
#
# [28513 rows x 17 columns]

# %%
gen_ed = gen.groupby(['precinct_name','contest_title','candidate_name'])['ballots_cast'].sum().reset_index()
gen_ed.head(5)
# Out:
#   precinct_name                                      contest_title  \
# 0        113001                     Member of Assembly District 13
# 1        113001                     Member of Assembly District 13
# 2        113001  Presidential Electors for President and Vice P...
# 3        113001  Presidential Electors for President and Vice P...
# 4        113001              Representative in Congress District 3
#
#            candidate_name  ballots_cast
# 0       Charles D. Lavine         427.0
# 1              Ruka Anzai         357.0
# 2         Donald J. Trump         443.0
# 3        Kamala D. Harris         404.0
# 4  Michael J. LiPetri Jr.         332.0

# %%
grouped = gen.groupby(['precinct_name','contest_title'])['ballots_cast'].sum().reset_index()
grouped.head(5)
# Out:
#   precinct_name                                      contest_title  \
# 0        113001                     Member of Assembly District 13
# 1        113001  Presidential Electors for President and Vice P...
# 2        113001              Representative in Congress District 3
# 3        113001                           State Senator District 7
# 4        113001                              United States Senator
#
#    ballots_cast
# 0         784.0
# 1         847.0
# 2         825.0
# 3         785.0
# 4         817.0

# %%
gen_ed.head(10)
# Out:
#   precinct_name                                      contest_title  \
# 0        113001                     Member of Assembly District 13
# 1        113001                     Member of Assembly District 13
# 2        113001  Presidential Electors for President and Vice P...
# 3        113001  Presidential Electors for President and Vice P...
# 4        113001              Representative in Congress District 3
# 5        113001              Representative in Congress District 3
# 6        113001                           State Senator District 7
# 7        113001                           State Senator District 7
# 8        113001                              United States Senator
# 9        113001                              United States Senator
#
#            candidate_name  ballots_cast
# 0       Charles D. Lavine         427.0
# 1              Ruka Anzai         357.0
# 2         Donald J. Trump         443.0
# 3        Kamala D. Harris         404.0
# 4  Michael J. LiPetri Jr.         332.0
# 5        Thomas R. Suozzi         493.0
# 6         Jack M. Martins         406.0
# 7           Kim Keiserman         379.0
# 8              Diane Sare           1.0
# 9   Kirsten E. Gillibrand         412.0

# %%
gen_ed = gen_ed.merge(grouped, on=['precinct_name', 'contest_title'], suffixes=('', '_total'))
gen_ed.head(5)
# Out:
#   precinct_name                                      contest_title  \
# 0        113001                     Member of Assembly District 13
# 1        113001                     Member of Assembly District 13
# 2        113001  Presidential Electors for President and Vice P...
# 3        113001  Presidential Electors for President and Vice P...
# 4        113001              Representative in Congress District 3
#
#            candidate_name  ballots_cast  ballots_cast_total
# 0       Charles D. Lavine         427.0               784.0
# 1              Ruka Anzai         357.0               784.0
# 2         Donald J. Trump         443.0               847.0
# 3        Kamala D. Harris         404.0               847.0
# 4  Michael J. LiPetri Jr.         332.0               825.0

# %%
gen_ed['percentage'] = (gen_ed['ballots_cast'] / gen_ed['ballots_cast_total']) * 100
gen_ed.head(10)
# Out:
#   precinct_name                                      contest_title  \
# 0        113001                     Member of Assembly District 13
# 1        113001                     Member of Assembly District 13
# 2        113001  Presidential Electors for President and Vice P...
# 3        113001  Presidential Electors for President and Vice P...
# 4        113001              Representative in Congress District 3
# 5        113001              Representative in Congress District 3
# 6        113001                           State Senator District 7
# 7        113001                           State Senator District 7
# 8        113001                              United States Senator
# 9        113001                              United States Senator
#
#            candidate_name  ballots_cast  ballots_cast_total  percentage
# 0       Charles D. Lavine         427.0               784.0   54.464286
# 1              Ruka Anzai         357.0               784.0   45.535714
# 2         Donald J. Trump         443.0               847.0   52.302243
# 3        Kamala D. Harris         404.0               847.0   47.697757
# 4  Michael J. LiPetri Jr.         332.0               825.0   40.242424
# 5        Thomas R. Suozzi         493.0               825.0   59.757576
# 6         Jack M. Martins         406.0               785.0   51.719745
# 7           Kim Keiserman         379.0               785.0   48.280255
# 8              Diane Sare           1.0               817.0    0.122399
# 9   Kirsten E. Gillibrand         412.0               817.0   50.428397

# %%
gen_ed[gen_ed['percentage'].isna()]
# Out:
#       precinct_name                                      contest_title  \
# 3891         218073                     Member of Assembly District 18
# 3892         218073                     Member of Assembly District 18
# 3893         218073  Presidential Electors for President and Vice P...
# 3894         218073  Presidential Electors for President and Vice P...
# 3895         218073              Representative in Congress District 4
# ...             ...                                                ...
# 12235        510701                           State Senator District 5
# 12236        510701                           State Senator District 5
# 12237        510701                              United States Senator
# 12238        510701                              United States Senator
# 12239        510701                              United States Senator
#
#                  candidate_name  ballots_cast  ballots_cast_total  percentage
# 3891   Danielle Samantha Smikle           0.0                 0.0         NaN
# 3892             Noah Burroughs           0.0                 0.0         NaN
# 3893            Donald J. Trump           0.0                 0.0         NaN
# 3894           Kamala D. Harris           0.0                 0.0         NaN
# 3895      Anthony P. D'Esposito           0.0                 0.0         NaN
# ...                         ...           ...                 ...         ...
# 12235                  Lisa Lin           0.0                 0.0         NaN
# 12236          Steven D. Rhoads           0.0                 0.0         NaN
# 12237                Diane Sare           0.0                 0.0         NaN
# 12238     Kirsten E. Gillibrand           0.0                 0.0         NaN
# 12239     Michael D. Sapraicone           0.0                 0.0         NaN
#
# [89 rows x 6 columns]

# %%
gen_ed.to_csv('gen_ed.csv')

# %%
gen_ed[gen_ed['precinct_name']=='510701']
# Out:
#       precinct_name                                      contest_title  \
# 12229        510701                     Member of Assembly District 10
# 12230        510701                     Member of Assembly District 10
# 12231        510701  Presidential Electors for President and Vice P...
# 12232        510701  Presidential Electors for President and Vice P...
# 12233        510701              Representative in Congress District 3
# 12234        510701              Representative in Congress District 3
# 12235        510701                           State Senator District 5
# 12236        510701                           State Senator District 5
# 12237        510701                              United States Senator
# 12238        510701                              United States Senator
# 12239        510701                              United States Senator
#
#                candidate_name  ballots_cast  ballots_cast_total  percentage
# 12229            Aamir Sultan           0.0                 0.0         NaN
# 12230             Steve Stern           0.0                 0.0         NaN
# 12231         Donald J. Trump           0.0                 0.0         NaN
# 12232        Kamala D. Harris           0.0                 0.0         NaN
# 12233  Michael J. LiPetri Jr.           0.0                 0.0         NaN
# 12234        Thomas R. Suozzi           0.0                 0.0         NaN
# 12235                Lisa Lin           0.0                 0.0         NaN
# 12236        Steven D. Rhoads           0.0                 0.0         NaN
# 12237              Diane Sare           0.0                 0.0         NaN
# 12238   Kirsten E. Gillibrand           0.0                 0.0         NaN
# 12239   Michael D. Sapraicone           0.0                 0.0         NaN

# %%
# Write a function to create a new column
# 'category' which tells us what kinda race it is

def extract_category(contest_title):
    if 'Assembly District' in contest_title:
        return 'Assembly District'
    elif 'Congress District' in contest_title:
        return 'Congressional District'
    elif 'State Senator District' in contest_title:
        return 'State Senate District'
    elif 'Presidential' in contest_title:
        return 'President'
    elif 'United States Senator' in contest_title:
        return 'US Senator'
    else:
        return 'Other'

# %%
gen_ed['category'] = gen_ed['contest_title'].apply(extract_category)
gen_ed.tail(10)
# Out:
#       precinct_name                                      contest_title  \
# 14584        517045                     Member of Assembly District 17
# 14585        517045  Presidential Electors for President and Vice P...
# 14586        517045  Presidential Electors for President and Vice P...
# 14587        517045              Representative in Congress District 3
# 14588        517045              Representative in Congress District 3
# 14589        517045                           State Senator District 8
# 14590        517045                           State Senator District 8
# 14591        517045                              United States Senator
# 14592        517045                              United States Senator
# 14593        517045                              United States Senator
#
#                candidate_name  ballots_cast  ballots_cast_total  percentage  \
# 14584         John K. Mikulin         154.0               274.0   56.204380
# 14585         Donald J. Trump         152.0               286.0   53.146853
# 14586        Kamala D. Harris         134.0               286.0   46.853147
# 14587  Michael J. LiPetri Jr.         146.0               282.0   51.773050
# 14588        Thomas R. Suozzi         136.0               282.0   48.226950
# 14589             Alexis Weik         149.0               272.0   54.779412
# 14590        Francis R. Dolan         123.0               272.0   45.220588
# 14591              Diane Sare           0.0               285.0    0.000000
# 14592   Kirsten E. Gillibrand         138.0               285.0   48.421053
# 14593   Michael D. Sapraicone         147.0               285.0   51.578947
#
#                      category
# 14584       Assembly District
# 14585               President
# 14586               President
# 14587  Congressional District
# 14588  Congressional District
# 14589   State Senate District
# 14590   State Senate District
# 14591              US Senator
# 14592              US Senator
# 14593              US Senator

# %%
# Checking if ballots_total adds up

grouped_df = gen_ed.groupby(['precinct_name', 'contest_title'], as_index=False).agg({
    'ballots_cast': 'sum',
    'ballots_cast_total': 'first'  # Keep the first occurrence of ballots_cast_total for comparison
})

# Check for any discrepancies
grouped_df['total_matches'] = grouped_df['ballots_cast'] == grouped_df['ballots_cast_total']

# Display rows where ballots_cast does not match ballots_cast_total
discrepancies = grouped_df[~grouped_df['total_matches']]

# Print summary
if discrepancies.empty:
    print("All ballots_cast totals match ballots_cast_total for each precinct and contest.")
else:
    print("Discrepancies found:")
    print(discrepancies[['precinct', 'contest', 'ballots_cast', 'ballots_cast_total']])
# Out:
# All ballots_cast totals match ballots_cast_total for each precinct and contest.

# %%
# Function to determine the President winner for each precinct, handling ties as specified

def determine_winner(group):
    group = group.dropna(subset=['percentage'])  # Skip rows with NaN percentages
    if not group.empty:
        max_percentage = group['percentage'].max()
        winners = group[group['percentage'] == max_percentage]  # Select all rows with the maximum percentage

        # Check if there is a tie (more than one candidate has the max percentage)
        if len(winners) > 1:
            # In the case of a tie, return specified values
            return pd.Series(['Tie', 50, winners['ballots_cast'].iloc[1], winners['ballots_cast_total'].max()], 
                             index=['race_winner', 'race_winning_perc', 'race_win_votes', 'ballots_cast_total'])
        else:
            # No tie, only one winner
            winner_row = winners.iloc[0]
            return pd.Series([winner_row['candidate_name'], max_percentage, winner_row['ballots_cast'], winner_row['ballots_cast_total']], 
                             index=['race_winner', 'race_winning_perc', 'race_win_votes', 'ballots_cast_total'])
    return pd.Series([None, None, None, None], index=['race_winner', 'race_winning_perc', 'race_win_votes', 'ballots_cast_total'])

# %%
# Apply the function to each precinct and create new columns 'President_winner' and 'winning_perc'
winners = gen_ed.groupby(['precinct_name','contest_title','category']).apply(determine_winner).reset_index()
winners
# Out:
#      precinct_name                                      contest_title  \
# 0           113001                     Member of Assembly District 13
# 1           113001  Presidential Electors for President and Vice P...
# 2           113001              Representative in Congress District 3
# 3           113001                           State Senator District 7
# 4           113001                              United States Senator
# ...            ...                                                ...
# 6144        517045                     Member of Assembly District 17
# 6145        517045  Presidential Electors for President and Vice P...
# 6146        517045              Representative in Congress District 3
# 6147        517045                           State Senator District 8
# 6148        517045                              United States Senator
#
#                     category             race_winner  race_winning_perc  \
# 0          Assembly District       Charles D. Lavine          54.464286
# 1                  President         Donald J. Trump          52.302243
# 2     Congressional District        Thomas R. Suozzi          59.757576
# 3      State Senate District         Jack M. Martins          51.719745
# 4                 US Senator   Kirsten E. Gillibrand          50.428397
# ...                      ...                     ...                ...
# 6144       Assembly District         John K. Mikulin          56.204380
# 6145               President         Donald J. Trump          53.146853
# 6146  Congressional District  Michael J. LiPetri Jr.          51.773050
# 6147   State Senate District             Alexis Weik          54.779412
# 6148              US Senator   Michael D. Sapraicone          51.578947
#
#       race_win_votes  ballots_cast_total
# 0              427.0               784.0
# 1              443.0               847.0
# 2              493.0               825.0
# 3              406.0               785.0
# 4              412.0               817.0
# ...              ...                 ...
# 6144           154.0               274.0
# 6145           152.0               286.0
# 6146           146.0               282.0
# 6147           149.0               272.0
# 6148           147.0               285.0
#
# [6149 rows x 7 columns]

# %%
gen_ed.to_csv('local_ed.csv')

# %%
# Function to get the President winner for each precinct

def get_prez_winner(group):
    prez_winner_row = group.loc[group['category'] == 'President']
    if not prez_winner_row.empty:
        prez_winner = prez_winner_row['race_winner'].values[0]
        prez_winning_perc = prez_winner_row['race_winning_perc'].values[0]
        prez_votes = prez_winner_row['race_win_votes'].values[0]
        prez_total_votes = prez_winner_row['ballots_cast_total'].values[0]
        return pd.Series([prez_winner, prez_winning_perc, prez_votes, prez_total_votes], index=['prez_winner', 'prez_winning_perc','prez_votes','prez_total_votes'])
    return pd.Series([None, None, None, None], index=['prez_winner', 'prez_winning_perc','prez_votes','prez_total_votes'])

# %%
# Apply the function to each precinct and create a new column 'prez_winner'

prez_winners = winners.groupby('precinct_name').apply(get_prez_winner).reset_index()
prez_winners
# Out:
#      precinct_name       prez_winner  prez_winning_perc  prez_votes  \
# 0           113001   Donald J. Trump          52.302243       443.0
# 1           113002  Kamala D. Harris          53.582555       344.0
# 2           113003  Kamala D. Harris          53.658537       242.0
# 3           113004   Donald J. Trump          54.499366       430.0
# 4           113005   Donald J. Trump          50.087260       287.0
# ...            ...               ...                ...         ...
# 1075        517041   Donald J. Trump          62.500000       210.0
# 1076        517042   Donald J. Trump         100.000000         1.0
# 1077        517043   Donald J. Trump          67.647059        23.0
# 1078        517044   Donald J. Trump          72.383721       249.0
# 1079        517045   Donald J. Trump          53.146853       152.0
#
#       prez_total_votes
# 0                847.0
# 1                642.0
# 2                451.0
# 3                789.0
# 4                573.0
# ...                ...
# 1075             336.0
# 1076               1.0
# 1077              34.0
# 1078             344.0
# 1079             286.0
#
# [1080 rows x 5 columns]

# %%
winners = winners.merge(prez_winners, on='precinct_name', how='left')
winners
# Out:
#      precinct_name                                      contest_title  \
# 0           113001                     Member of Assembly District 13
# 1           113001  Presidential Electors for President and Vice P...
# 2           113001              Representative in Congress District 3
# 3           113001                           State Senator District 7
# 4           113001                              United States Senator
# ...            ...                                                ...
# 6144        517045                     Member of Assembly District 17
# 6145        517045  Presidential Electors for President and Vice P...
# 6146        517045              Representative in Congress District 3
# 6147        517045                           State Senator District 8
# 6148        517045                              United States Senator
#
#                     category             race_winner  race_winning_perc  \
# 0          Assembly District       Charles D. Lavine          54.464286
# 1                  President         Donald J. Trump          52.302243
# 2     Congressional District        Thomas R. Suozzi          59.757576
# 3      State Senate District         Jack M. Martins          51.719745
# 4                 US Senator   Kirsten E. Gillibrand          50.428397
# ...                      ...                     ...                ...
# 6144       Assembly District         John K. Mikulin          56.204380
# 6145               President         Donald J. Trump          53.146853
# 6146  Congressional District  Michael J. LiPetri Jr.          51.773050
# 6147   State Senate District             Alexis Weik          54.779412
# 6148              US Senator   Michael D. Sapraicone          51.578947
#
#       race_win_votes  ballots_cast_total      prez_winner  prez_winning_perc  \
# 0              427.0               784.0  Donald J. Trump          52.302243
# 1              443.0               847.0  Donald J. Trump          52.302243
# 2              493.0               825.0  Donald J. Trump          52.302243
# 3              406.0               785.0  Donald J. Trump          52.302243
# 4              412.0               817.0  Donald J. Trump          52.302243
# ...              ...                 ...              ...                ...
# 6144           154.0               274.0  Donald J. Trump          53.146853
# 6145           152.0               286.0  Donald J. Trump          53.146853
# 6146           146.0               282.0  Donald J. Trump          53.146853
# 6147           149.0               272.0  Donald J. Trump          53.146853
# 6148           147.0               285.0  Donald J. Trump          53.146853
#
#       prez_votes  prez_total_votes
# 0          443.0             847.0
# 1          443.0             847.0
# 2          443.0             847.0
# 3          443.0             847.0
# 4          443.0             847.0
# ...          ...               ...
# 6144       152.0             286.0
# 6145       152.0             286.0
# 6146       152.0             286.0
# 6147       152.0             286.0
# 6148       152.0             286.0
#
# [6149 rows x 11 columns]

# %%
winners.head(15)
# Out:
#    precinct_name                                      contest_title  \
# 0         113001                     Member of Assembly District 13
# 1         113001  Presidential Electors for President and Vice P...
# 2         113001              Representative in Congress District 3
# 3         113001                           State Senator District 7
# 4         113001                              United States Senator
# 5         113002                     Member of Assembly District 13
# 6         113002  Presidential Electors for President and Vice P...
# 7         113002              Representative in Congress District 3
# 8         113002                           State Senator District 7
# 9         113002                              United States Senator
# 10        113003                     Member of Assembly District 13
# 11        113003  Presidential Electors for President and Vice P...
# 12        113003              Representative in Congress District 3
# 13        113003                           State Senator District 7
# 14        113003                              United States Senator
#
#                   category            race_winner  race_winning_perc  \
# 0        Assembly District      Charles D. Lavine          54.464286
# 1                President        Donald J. Trump          52.302243
# 2   Congressional District       Thomas R. Suozzi          59.757576
# 3    State Senate District        Jack M. Martins          51.719745
# 4               US Senator  Kirsten E. Gillibrand          50.428397
# 5        Assembly District      Charles D. Lavine          57.382550
# 6                President       Kamala D. Harris          53.582555
# 7   Congressional District       Thomas R. Suozzi          61.538462
# 8    State Senate District          Kim Keiserman          51.505017
# 9               US Senator  Kirsten E. Gillibrand          53.697749
# 10       Assembly District      Charles D. Lavine          61.137441
# 11               President       Kamala D. Harris          53.658537
# 12  Congressional District       Thomas R. Suozzi          62.500000
# 13   State Senate District          Kim Keiserman          56.000000
# 14              US Senator  Kirsten E. Gillibrand          57.471264
#
#     race_win_votes  ballots_cast_total       prez_winner  prez_winning_perc  \
# 0            427.0               784.0   Donald J. Trump          52.302243
# 1            443.0               847.0   Donald J. Trump          52.302243
# 2            493.0               825.0   Donald J. Trump          52.302243
# 3            406.0               785.0   Donald J. Trump          52.302243
# 4            412.0               817.0   Donald J. Trump          52.302243
# 5            342.0               596.0  Kamala D. Harris          53.582555
# 6            344.0               642.0  Kamala D. Harris          53.582555
# 7            384.0               624.0  Kamala D. Harris          53.582555
# 8            308.0               598.0  Kamala D. Harris          53.582555
# 9            334.0               622.0  Kamala D. Harris          53.582555
# 10           258.0               422.0  Kamala D. Harris          53.658537
# 11           242.0               451.0  Kamala D. Harris          53.658537
# 12           275.0               440.0  Kamala D. Harris          53.658537
# 13           238.0               425.0  Kamala D. Harris          53.658537
# 14           250.0               435.0  Kamala D. Harris          53.658537
#
#     prez_votes  prez_total_votes
# 0        443.0             847.0
# 1        443.0             847.0
# 2        443.0             847.0
# 3        443.0             847.0
# 4        443.0             847.0
# 5        344.0             642.0
# 6        344.0             642.0
# 7        344.0             642.0
# 8        344.0             642.0
# 9        344.0             642.0
# 10       242.0             451.0
# 11       242.0             451.0
# 12       242.0             451.0
# 13       242.0             451.0
# 14       242.0             451.0

# %%
winners.groupby('precinct_name')['prez_total_votes'].sum()
# Out:
# precinct_name
# 113001    4235.0
# 113002    3210.0
# 113003    2255.0
# 113004    3945.0
# 113005    2865.0
#            ...
# 517041    1680.0
# 517042       5.0
# 517043     170.0
# 517044    1720.0
# 517045    1430.0
# Name: prez_total_votes, Length: 1080, dtype: float64

# %%
# winners = winners[winners['category'] != 'President']
winners
# Out:
#      precinct_name                                      contest_title  \
# 0           113001                     Member of Assembly District 13
# 1           113001  Presidential Electors for President and Vice P...
# 2           113001              Representative in Congress District 3
# 3           113001                           State Senator District 7
# 4           113001                              United States Senator
# ...            ...                                                ...
# 6144        517045                     Member of Assembly District 17
# 6145        517045  Presidential Electors for President and Vice P...
# 6146        517045              Representative in Congress District 3
# 6147        517045                           State Senator District 8
# 6148        517045                              United States Senator
#
#                     category             race_winner  race_winning_perc  \
# 0          Assembly District       Charles D. Lavine          54.464286
# 1                  President         Donald J. Trump          52.302243
# 2     Congressional District        Thomas R. Suozzi          59.757576
# 3      State Senate District         Jack M. Martins          51.719745
# 4                 US Senator   Kirsten E. Gillibrand          50.428397
# ...                      ...                     ...                ...
# 6144       Assembly District         John K. Mikulin          56.204380
# 6145               President         Donald J. Trump          53.146853
# 6146  Congressional District  Michael J. LiPetri Jr.          51.773050
# 6147   State Senate District             Alexis Weik          54.779412
# 6148              US Senator   Michael D. Sapraicone          51.578947
#
#       race_win_votes  ballots_cast_total      prez_winner  prez_winning_perc  \
# 0              427.0               784.0  Donald J. Trump          52.302243
# 1              443.0               847.0  Donald J. Trump          52.302243
# 2              493.0               825.0  Donald J. Trump          52.302243
# 3              406.0               785.0  Donald J. Trump          52.302243
# 4              412.0               817.0  Donald J. Trump          52.302243
# ...              ...                 ...              ...                ...
# 6144           154.0               274.0  Donald J. Trump          53.146853
# 6145           152.0               286.0  Donald J. Trump          53.146853
# 6146           146.0               282.0  Donald J. Trump          53.146853
# 6147           149.0               272.0  Donald J. Trump          53.146853
# 6148           147.0               285.0  Donald J. Trump          53.146853
#
#       prez_votes  prez_total_votes
# 0          443.0             847.0
# 1          443.0             847.0
# 2          443.0             847.0
# 3          443.0             847.0
# 4          443.0             847.0
# ...          ...               ...
# 6144       152.0             286.0
# 6145       152.0             286.0
# 6146       152.0             286.0
# 6147       152.0             286.0
# 6148       152.0             286.0
#
# [6149 rows x 11 columns]

# %%
winners['losing_prez_votes'] = winners['prez_total_votes'] - winners['prez_votes']
winners.head(16)
# Out:
#    precinct_name                                      contest_title  \
# 0         113001                     Member of Assembly District 13
# 1         113001  Presidential Electors for President and Vice P...
# 2         113001              Representative in Congress District 3
# 3         113001                           State Senator District 7
# 4         113001                              United States Senator
# 5         113002                     Member of Assembly District 13
# 6         113002  Presidential Electors for President and Vice P...
# 7         113002              Representative in Congress District 3
# 8         113002                           State Senator District 7
# 9         113002                              United States Senator
# 10        113003                     Member of Assembly District 13
# 11        113003  Presidential Electors for President and Vice P...
# 12        113003              Representative in Congress District 3
# 13        113003                           State Senator District 7
# 14        113003                              United States Senator
# 15        113004                     Member of Assembly District 13
#
#                   category            race_winner  race_winning_perc  \
# 0        Assembly District      Charles D. Lavine          54.464286
# 1                President        Donald J. Trump          52.302243
# 2   Congressional District       Thomas R. Suozzi          59.757576
# 3    State Senate District        Jack M. Martins          51.719745
# 4               US Senator  Kirsten E. Gillibrand          50.428397
# 5        Assembly District      Charles D. Lavine          57.382550
# 6                President       Kamala D. Harris          53.582555
# 7   Congressional District       Thomas R. Suozzi          61.538462
# 8    State Senate District          Kim Keiserman          51.505017
# 9               US Senator  Kirsten E. Gillibrand          53.697749
# 10       Assembly District      Charles D. Lavine          61.137441
# 11               President       Kamala D. Harris          53.658537
# 12  Congressional District       Thomas R. Suozzi          62.500000
# 13   State Senate District          Kim Keiserman          56.000000
# 14              US Senator  Kirsten E. Gillibrand          57.471264
# 15       Assembly District      Charles D. Lavine          52.162162
#
#     race_win_votes  ballots_cast_total       prez_winner  prez_winning_perc  \
# 0            427.0               784.0   Donald J. Trump          52.302243
# 1            443.0               847.0   Donald J. Trump          52.302243
# 2            493.0               825.0   Donald J. Trump          52.302243
# 3            406.0               785.0   Donald J. Trump          52.302243
# 4            412.0               817.0   Donald J. Trump          52.302243
# 5            342.0               596.0  Kamala D. Harris          53.582555
# 6            344.0               642.0  Kamala D. Harris          53.582555
# 7            384.0               624.0  Kamala D. Harris          53.582555
# 8            308.0               598.0  Kamala D. Harris          53.582555
# 9            334.0               622.0  Kamala D. Harris          53.582555
# 10           258.0               422.0  Kamala D. Harris          53.658537
# 11           242.0               451.0  Kamala D. Harris          53.658537
# 12           275.0               440.0  Kamala D. Harris          53.658537
# 13           238.0               425.0  Kamala D. Harris          53.658537
# 14           250.0               435.0  Kamala D. Harris          53.658537
# 15           386.0               740.0   Donald J. Trump          54.499366
#
#     prez_votes  prez_total_votes  losing_prez_votes
# 0        443.0             847.0              404.0
# 1        443.0             847.0              404.0
# 2        443.0             847.0              404.0
# 3        443.0             847.0              404.0
# 4        443.0             847.0              404.0
# 5        344.0             642.0              298.0
# 6        344.0             642.0              298.0
# 7        344.0             642.0              298.0
# 8        344.0             642.0              298.0
# 9        344.0             642.0              298.0
# 10       242.0             451.0              209.0
# 11       242.0             451.0              209.0
# 12       242.0             451.0              209.0
# 13       242.0             451.0              209.0
# 14       242.0             451.0              209.0
# 15       430.0             789.0              359.0

# %%
winners.to_csv('nassau_race_winners.csv')

# %% [markdown]
# **Post analysis:**
# Simultaneously, as I analyzed TC's data, I realized it only included Nassau. The nightmare was real. Only data for parts of assembly districts and congressional seats in Nassau. Suffolk's data was not just in ASCII, it was in PDF format. I remember feeding ChatGPT the coded PDF as well as the results layout. It spouted out one .csv with separate columns. I cannot remember now if it was decoded or if I used excel functions to do that (most likely the latter). All these files sit on my Newsday desktop Data -> Election 2024 -> Results and analysis. I will also leave a backup on my karnam.news Drive.

# %%
# We are going to try a code that automates
# the calculation of percentage winning by district
# Let's begin with CD4

district = winners[winners['contest_title']=='Representative in Congress District 4']
total_prez = district['prez_total_votes'].sum()
votes_harris = district[district['prez_winner']=='Kamala D. Harris']
votes_trump = district[district['prez_winner']=='Donald J. Trump']
votes_tie = district[district['prez_winner']=='Tie']
total_harris = votes_harris['prez_votes'].sum() + votes_trump['losing_prez_votes'].sum() + votes_tie['prez_votes'].sum()
total_trump = votes_trump['prez_votes'].sum() + votes_harris['losing_prez_votes'].sum() + votes_tie['prez_votes'].sum()
perc_harris = total_harris/total_prez * 100
perc_trump = total_trump/total_prez * 100

print("Total sum of all prezident votes in CD-4:", total_prez)
# print("Votes won by Hariss in CD3:", votes_harris)
# print("Votes by Hariss in AD-20:", total_harris)
# print("Votes by Trump in AD-20:", total_trump)
print(f"Harris %: {perc_harris:.2f}, Trump %: {perc_trump:.2f}")
# Out:
# Total sum of all prezident votes in CD-4: 372655.0
# Harris %: 50.55, Trump %: 49.45
